# %%
import pandas as pd
import plotly
import qgrid
import relatively

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Reactions and Enzyme Commission
#
# ECs are hierarchical though the lower you get into the hierarchy the less helpful these plots can be. Their intention is to give a brief overview of what's happening across our samples at given levels.
#
# With ECs, we have 4 levels. Because the values of the levels are numeric we will have to specify which columns represent the hierarchy and which represent the values.
#
# Taking a look at our table:

# %%
df = pd.read_table("../data/reactions.txt")
qgrid.show_grid(df)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# Each level of ECs are dependent on the previous level to make sense, so we will specify `dependent`:

# %%
fig = relatively.abundance_figure(
    "../data/reactions.txt", ["class", "subclass", "subsubclass"],
    ["sample1", "sample2", "sample3", "sample4", "sample5"],
    title="Observed Reactions (EC)",
    dependent=".")
plotly.offline.iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# <div id="ac2136f7-7ebf-4e9c-9895-68609e2bb100" style="height: 700px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'ac2136f7-7ebf-4e9c-9895-68609e2bb100',
#             [{"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "2", "text": "2", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [22464.0, 21603.0, 36572.0, 34279.0, 37650.0], "type": "bar", "uid": "802f22c8-7f0b-11e8-8772-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "1", "text": "1", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [21834.0, 18735.0, 30919.0, 27749.0, 25559.0], "type": "bar", "uid": "80337de6-7f0b-11e8-9d7c-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "3", "text": "3", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [16128.0, 14968.0, 26884.0, 23557.0, 26429.0], "type": "bar", "uid": "8035ebd0-7f0b-11e8-bebe-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "6", "text": "6", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [6868.0, 6880.0, 11001.0, 9648.0, 11065.0], "type": "bar", "uid": "80384c9a-7f0b-11e8-bcb2-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "4", "text": "4", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [5903.0, 6038.0, 9274.0, 8070.0, 9050.0], "type": "bar", "uid": "803ae70c-7f0b-11e8-85c6-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "5", "text": "5", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [4218.0, 3839.0, 6866.0, 6757.0, 8531.0], "type": "bar", "uid": "803d4902-7f0b-11e8-8393-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#e377c2"}, "name": "-", "text": "-", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [1569.0, 1517.0, 2242.0, 2155.0, 2542.0], "type": "bar", "uid": "803fbaa2-7f0b-11e8-bdc3-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "2", "text": "2", "visible": true, "x": ["sample1", "sample2", "sample3", "sample4", "sample5"], "y": [29.359880402283228, 28.441203281677303, 29.55122093117213, 30.547609499621263, 31.160511810371936], "type": "bar", "uid": "80423a34-7f0b-11e8-a2ec-acbc3295e99b", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "1", "text": "1", "visible": true, "x": ["sample1", "sample2", "sample3", "sample4", "sample5"], "y": [25.462082087523786, 27.643573381950777, 24.983435414276247, 24.728423116339172, 21.153559664310663], "type": "bar", "uid": "8045327a-7f0b-11e8-aa89-acbc3295e99b", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "3", "text": "3", "visible": true, "x": ["sample1", "sample2", "sample3", "sample4", "sample5"], "y": [20.34248437075292, 20.419325432999088, 21.72304012669888, 20.992737156351645, 21.873603363514476], "type": "bar", "uid": "8048054a-7f0b-11e8-a675-acbc3295e99b", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "6", "text": "6", "visible": true, "x": ["sample1", "sample2", "sample3", "sample4", "sample5"], "y": [9.350366947540092, 8.695431986225058, 8.889122319365212, 8.597781045314798, 9.157797162862298], "type": "bar", "uid": "804acf98-7f0b-11e8-904a-acbc3295e99b", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "4", "text": "4", "visible": true, "x": ["sample1", "sample2", "sample3", "sample4", "sample5"], "y": [8.206034248437074, 7.473665552516966, 7.49365697571066, 7.191551931559951, 7.490109744591396], "type": "bar", "uid": "804d9140-7f0b-11e8-a68c-acbc3295e99b", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "5", "text": "5", "visible" ...

# %% [markdown]
# # Taxonomic Composition of Metagenomes
#
# The hierarchy of taxonomies can be used to summarize and order samples. In this example we will reorganize our samples based on their Shannon diversity index.
#
# Our input table looks like:

# %%
df = pd.read_table("../data/taxonomy.txt")
qgrid.show_grid(df)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# In the case of taxonomy, each level treated independently still makes biological sense, so we'll leave off `dependent`.

# %%
fig = relatively.abundance_figure(
    "../data/taxonomy.txt", ["phylum", "class", "order"],
    title="Taxonomy Assignment Summary",
    height=900)
plotly.offline.iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# <div id="02ca588a-38ed-42c6-8513-1336842afbbf" style="height: 900px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '02ca588a-38ed-42c6-8513-1336842afbbf',
#             [{"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "Proteobacteria", "text": "Proteobacteria", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [209154.0, 123722.0, 130103.0, 386937.0, 398612.0], "type": "bar", "uid": "863614c6-7f0b-11e8-80e8-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "Firmicutes", "text": "Firmicutes", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [75491.0, 42435.0, 49384.0, 224883.0, 191771.0], "type": "bar", "uid": "8638f450-7f0b-11e8-a738-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "NA", "text": "NA", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [93418.0, 21294.0, 22892.0, 58668.0, 48267.0], "type": "bar", "uid": "863bbbe2-7f0b-11e8-8e7e-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "Bacteroidetes", "text": "Bacteroidetes", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [22949.0, 16805.0, 8502.0, 40596.0, 109766.0], "type": "bar", "uid": "863e614c-7f0b-11e8-89d0-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "Actinobacteria", "text": "Actinobacteria", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [43490.0, 25112.0, 32005.0, 37189.0, 27313.0], "type": "bar", "uid": "8640fce8-7f0b-11e8-92c6-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "Acidobacteria", "text": "Acidobacteria", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [39116.0, 29581.0, 30956.0, 58181.0, 4836.0], "type": "bar", "uid": "86439be4-7f0b-11e8-bb10-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#e377c2"}, "name": "Ascomycota", "text": "Ascomycota", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [127648.0, 6111.0, 10210.0, 4075.0, 3055.0], "type": "bar", "uid": "86464134-7f0b-11e8-8495-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#7f7f7f"}, "name": "Chloroflexi", "text": "Chloroflexi", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [15657.0, 11183.0, 9230.0, 12401.0, 10969.0], "type": "bar", "uid": "8648e522-7f0b-11e8-a364-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#bcbd22"}, "name": "Gemmatimonadetes", "text": "Gemmatimonadetes", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [8801.0, 7220.0, 6780.0, 11578.0, 579.0], "type": "bar", "uid": "864bb998-7f0b-11e8-9bb4-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#17becf"}, "name": "Verrucomicrobia", "text": "Verrucomicrobia", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [9414.0, 5047.0, 7618.0, 7704.0, 1898.0], "type": "bar", "uid": "864eceec-7f0b-11e8-bf66-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "Basidiomycota", "text": "Basidiomycota", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [12370.0, 1832.0, 3389.0, 1197.0, 3089.0], "type": "bar", "uid": "86518efa-7f0b-11e8-a924-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "Chlamydiae", "text": "Chlamydiae", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [3527.0, 1835.0, 2154.0, 7779.0, 5789.0], "type": "bar", "uid": "86544174-7f0b-11e8-a71b-acbc3295e99b", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "Planctomycetes", "text": "Planct ...

# %% [markdown]
# # Diversity Across Samples
#
# To get diversity indexes per sample, there's a convenience function to calculate each on a dataframe:

# %%
diversities = relatively.calculate_diversity(
    df, ["phylum", "class", "order"],
    ["sample1", "sample2", "sample3", "sample4", "sample5"],
    ["shannon", "simpson", "invsimpson"])
qgrid.show_grid(diversities)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
