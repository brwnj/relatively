# %%
import pandas as pd
import plotly
import relatively

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Reactions and Enzyme Commission
#
# ECs are hierarchical though the lower you get into the hierarchy the less helpful these plots can be. Their intention is to give a brief overview of what's happening across our samples at given levels.
#
# With ECs, we have 4 levels. Because the values of the levels are numeric we will have to specify which columns represent the hierarchy and which represent the values.
#
# Taking a look at our table:

# %%
df = pd.read_table("../data/reactions.txt")
df.head()
# Out:
#   class subclass subsubclass serialid  sample1  sample2  sample3  sample4  \
# 0     1        -           -        -    117.0     98.0    207.0    127.0
# 1     1        1           -        -      1.0      7.0      6.0     16.0
# 2     1        1           1        -    248.0    364.0    358.0    400.0
# 3     1        1           1        -      8.0      4.0     12.0      8.0
# 4     1        1           1        1     83.0    101.0    210.0     92.0
#
#    sample5
# 0    409.0
# 1     69.0
# 2    400.0
# 3     14.0
# 4     37.0

# %% [markdown]
# Each level of ECs are dependent on the previous level to make sense, so we will specify `dependent`:

# %%
fig = relatively.abundance_figure(
    "../data/reactions.txt", ["class", "subclass", "subsubclass"],
    ["sample1", "sample2", "sample3", "sample4", "sample5"],
    title="Observed Reactions (EC)",
    dependent=".")
plotly.offline.iplot(fig)
# Out:
# <div id="02b756ed-6dfe-49e1-a771-cdab0a325654" style="height: 700px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("02b756ed-6dfe-49e1-a771-cdab0a325654", [{"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "2", "text": "2", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [22464.0, 21603.0, 36572.0, 34279.0, 37650.0], "type": "bar", "uid": "dec1055c-ef79-4c56-9529-dcb707b8d38d", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "1", "text": "1", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [21834.0, 18735.0, 30919.0, 27749.0, 25559.0], "type": "bar", "uid": "8f64c9cd-3130-489c-8c53-db2c0ce4bcfa", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "3", "text": "3", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [16128.0, 14968.0, 26884.0, 23557.0, 26429.0], "type": "bar", "uid": "3b5c250f-ea34-49f8-81ef-6fa3fb096fa5", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "6", "text": "6", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [6868.0, 6880.0, 11001.0, 9648.0, 11065.0], "type": "bar", "uid": "a2a27293-2577-4885-8466-d776a8a88429", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "4", "text": "4", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [5903.0, 6038.0, 9274.0, 8070.0, 9050.0], "type": "bar", "uid": "21592da6-60f4-4d72-a610-a74847be080c", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "5", "text": "5", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [4218.0, 3839.0, 6866.0, 6757.0, 8531.0], "type": "bar", "uid": "a0e2a7fe-91b4-4e70-99bd-d2ee7601eb54", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#e377c2"}, "name": "-", "text": "-", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [1569.0, 1517.0, 2242.0, 2155.0, 2542.0], "type": "bar", "uid": "61d540c2-d60b-403e-b03c-9d0428ce1b7d", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "2", "text": "2", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [28.441203281677303, 29.359880402283228, 29.55122093117213, 30.547609499621263, 31.160511810371936], "type": "bar", "uid": "9fc9e0e7-bd36-4992-88d3-cf5d327d6fb6", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "1", "text": "1", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [27.643573381950777, 25.462082087523786, 24.983435414276247, 24.728423116339172, 21.153559664310663], "type": "bar", "uid": "e148dd61-8099-4169-aad0-9c9a074e1f00", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "3", "text": "3", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [20.419325432999088, 20.34248437075292, 21.72304012669888, 20.992737156351645, 21.873603363514476], "type": "bar", "uid": "ac64ee9f-fc95-4584-9965-5e30751343c9", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "6", "text": "6", "visible": true, "x": ["sample2", "sample1", "sample3", "sample4", "sample5"], "y": [8.695431986225058, 9.350366947540092, 8.889122319365212, 8.597781045314798, 9.157797162862298], "type": "bar", "uid": "d48ee7b4-920b-4474-9b04-80202b8ed717", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "4", "text": "4", "visible": true, "x": ["sample2", "sample1", "sample ...

# %%
# Should also work when samples are numbers...
# sample5 -> 7 is intentional to show no space when plotly generates the plot
df.rename(columns={"sample1":1, "sample2":2, "sample3":3, "sample4":4, "sample5":7}, inplace=True)
df.head()
# Out:
#   class subclass subsubclass serialid      1      2      3      4      7
# 0     1        -           -        -  117.0   98.0  207.0  127.0  409.0
# 1     1        1           -        -    1.0    7.0    6.0   16.0   69.0
# 2     1        1           1        -  248.0  364.0  358.0  400.0  400.0
# 3     1        1           1        -    8.0    4.0   12.0    8.0   14.0
# 4     1        1           1        1   83.0  101.0  210.0   92.0   37.0

# %%
hierarchy = ["class", "subclass", "subsubclass"]
dfs = relatively.get_dfs_across_hierarchy(df, hierarchy, [1, 2, 3, 4, 7], dependent=".")
fig = relatively.get_abundance_figure_from_dfs(dfs, hierarchy)
plotly.offline.iplot(fig)
# Out:
# <div id="0f6926e0-ae12-48e7-b11c-a9bb6239d13e" style="height: 700px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0f6926e0-ae12-48e7-b11c-a9bb6239d13e", [{"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "2", "text": "2", "visible": true, "x": [2, 1, 3, 4, 7], "y": [22464.0, 21603.0, 36572.0, 34279.0, 37650.0], "type": "bar", "uid": "9a84c6fc-1732-4675-ad17-a130b98df6ad", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "1", "text": "1", "visible": true, "x": [2, 1, 3, 4, 7], "y": [21834.0, 18735.0, 30919.0, 27749.0, 25559.0], "type": "bar", "uid": "52e10760-8e1a-42a4-9cce-ccbf1360a58c", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "3", "text": "3", "visible": true, "x": [2, 1, 3, 4, 7], "y": [16128.0, 14968.0, 26884.0, 23557.0, 26429.0], "type": "bar", "uid": "7fdf834a-1a7e-4b45-adc0-80e4b3d88aed", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "6", "text": "6", "visible": true, "x": [2, 1, 3, 4, 7], "y": [6868.0, 6880.0, 11001.0, 9648.0, 11065.0], "type": "bar", "uid": "f425678f-5e40-49e1-96d1-8b026ad4184f", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "4", "text": "4", "visible": true, "x": [2, 1, 3, 4, 7], "y": [5903.0, 6038.0, 9274.0, 8070.0, 9050.0], "type": "bar", "uid": "fd9d6efe-726c-45d4-9fc9-31404de4fc74", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "5", "text": "5", "visible": true, "x": [2, 1, 3, 4, 7], "y": [4218.0, 3839.0, 6866.0, 6757.0, 8531.0], "type": "bar", "uid": "3a89b12c-fca4-4359-8f80-6c0cc12a3021", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#e377c2"}, "name": "-", "text": "-", "visible": true, "x": [2, 1, 3, 4, 7], "y": [1569.0, 1517.0, 2242.0, 2155.0, 2542.0], "type": "bar", "uid": "6c9ae220-d307-448d-a4a1-1a95a662f1dc", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "2", "text": "2", "visible": true, "x": [2, 1, 3, 4, 7], "y": [28.441203281677303, 29.359880402283228, 29.55122093117213, 30.547609499621263, 31.160511810371936], "type": "bar", "uid": "9bfd9644-8e54-4c21-bb0b-ee6684f15bce", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "1", "text": "1", "visible": true, "x": [2, 1, 3, 4, 7], "y": [27.643573381950777, 25.462082087523786, 24.983435414276247, 24.728423116339172, 21.153559664310663], "type": "bar", "uid": "ba769611-9642-4c53-ac92-8e9fe98fb555", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "3", "text": "3", "visible": true, "x": [2, 1, 3, 4, 7], "y": [20.419325432999088, 20.34248437075292, 21.72304012669888, 20.992737156351645, 21.873603363514476], "type": "bar", "uid": "5fd41f8a-dca7-47ba-ba5a-04e20af8d6aa", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "6", "text": "6", "visible": true, "x": [2, 1, 3, 4, 7], "y": [8.695431986225058, 9.350366947540092, 8.889122319365212, 8.597781045314798, 9.157797162862298], "type": "bar", "uid": "ce51f63a-9b41-41ee-950e-cbce9e088af7", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "4", "text": "4", "visible": true, "x": [2, 1, 3, 4, 7], "y": [7.473665552516966, 8.206034248437074, 7.49365697571066, 7.191551931559951, 7.490109744591396], "type": "bar", "uid": "a1563b72-d286-4e01-9a67-1c7d4fd1b190", "xaxis": "x", "yaxis": "y2"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "5", "text": "5", "visible": true, "x": [2, 1, 3, 4, 7], "y": [5.340322090549985, 5.217450394128839, 5.547924174598814, 6.021476629684089, 7.060566434376707], "type": "bar", "uid": "21e239f7-ae60- ...

# %% [markdown]
# # Taxonomic Composition of Metagenomes
#
# The hierarchy of taxonomies can be used to summarize and order samples. In this example we will reorganize our samples based on their Shannon diversity index.
#
# Our input table looks like:

# %%
df = pd.read_table("../data/taxonomy.txt")
df.head()
# Out:
#   superkingdom                        phylum class            order  sample1  \
# 0      Archaea     Candidatus Bathyarchaeota   NaN              NaN    123.0
# 1      Archaea      Candidatus Lokiarchaeota   NaN              NaN      4.0
# 2      Archaea      Candidatus Micrarchaeota   NaN              NaN      9.0
# 3      Archaea  Candidatus Nanohaloarchaeota   NaN  Nanohaloarchaea      1.0
# 4      Archaea      Candidatus Odinarchaeota   NaN              NaN      2.0
#
#    sample2  sample3  sample4  sample5
# 0    120.0    486.0    818.0   3253.0
# 1      1.0      9.0      2.0      5.0
# 2     13.0      9.0     19.0     14.0
# 3      2.0      2.0      1.0      0.0
# 4      0.0      2.0      3.0      6.0

# %% [markdown]
# In the case of taxonomy, each level treated independently still makes biological sense, so we'll leave off `dependent`.

# %%
fig = relatively.abundance_figure(
    "../data/taxonomy.txt", ["phylum", "class", "order"],
    title="Taxonomy Assignment Summary",
    height=900)
plotly.offline.iplot(fig)
# Out:
# <div id="64d3152c-1376-4a2c-94e7-e01cffa4f878" style="height: 900px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("64d3152c-1376-4a2c-94e7-e01cffa4f878", [{"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "Proteobacteria", "text": "Proteobacteria", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [209154.0, 123722.0, 130103.0, 386937.0, 398612.0], "type": "bar", "uid": "8fb7b1c2-33f4-48cc-b20b-24bd5271f115", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "Firmicutes", "text": "Firmicutes", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [75491.0, 42435.0, 49384.0, 224883.0, 191771.0], "type": "bar", "uid": "96717a69-7e9c-4d2e-b373-7410ad0d9289", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#2ca02c"}, "name": "NA", "text": "NA", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [93418.0, 21294.0, 22892.0, 58668.0, 48267.0], "type": "bar", "uid": "e2d8effa-3163-4e87-9408-46c47db0fc80", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#d62728"}, "name": "Bacteroidetes", "text": "Bacteroidetes", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [22949.0, 16805.0, 8502.0, 40596.0, 109766.0], "type": "bar", "uid": "31aa4226-1211-4901-a6dd-d648f48b6518", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#9467bd"}, "name": "Actinobacteria", "text": "Actinobacteria", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [43490.0, 25112.0, 32005.0, 37189.0, 27313.0], "type": "bar", "uid": "b5bcfd08-c685-473c-a078-986096bf3eb3", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#8c564b"}, "name": "Acidobacteria", "text": "Acidobacteria", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [39116.0, 29581.0, 30956.0, 58181.0, 4836.0], "type": "bar", "uid": "40832b29-593e-4855-b7c8-ea50391fb3da", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#e377c2"}, "name": "Ascomycota", "text": "Ascomycota", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [127648.0, 6111.0, 10210.0, 4075.0, 3055.0], "type": "bar", "uid": "36373f6a-d369-4acc-98b1-415221ec9366", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#7f7f7f"}, "name": "Chloroflexi", "text": "Chloroflexi", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [15657.0, 11183.0, 9230.0, 12401.0, 10969.0], "type": "bar", "uid": "9d28ecd8-7bd6-4aab-9428-a0c61a62a0ae", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#bcbd22"}, "name": "Gemmatimonadetes", "text": "Gemmatimonadetes", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [8801.0, 7220.0, 6780.0, 11578.0, 579.0], "type": "bar", "uid": "bbc2b268-20cd-4c15-bb4e-c41742737544", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#17becf"}, "name": "Verrucomicrobia", "text": "Verrucomicrobia", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [9414.0, 5047.0, 7618.0, 7704.0, 1898.0], "type": "bar", "uid": "309fe6b2-ef4f-478a-ad23-a5f21d9b4549", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#1f77b4"}, "name": "Basidiomycota", "text": "Basidiomycota", "visible": true, "x": ["sample3", "sample2", "sample1", "sample4", "sample5"], "y": [12370.0, 1832.0, 3389.0, 1197.0, 3089.0], "type": "bar", "uid": "21d5976e-09e4-4b3c-b4bb-37639addc836", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text+y", "marker": {"color": "#ff7f0e"}, "name": "Chlamydiae", "text": "Chlamydiae", "vi ...

# %% [markdown]
# # Diversity Across Samples
#
# To get diversity indexes per sample, there's a convenience function to calculate each on a dataframe:

# %%
diversities = relatively.calculate_diversity(
    df, ["phylum", "class", "order"],
    ["sample1", "sample2", "sample3", "sample4", "sample5"],
    ["shannon", "simpson", "invsimpson"])
diversities.head()
# Out:
#           shannon   simpson  invsimpson
# sample1  3.326696  0.902060   10.210381
# sample2  3.409359  0.917576   12.132366
# sample3  3.686257  0.940822   16.898295
# sample4  2.593147  0.821694    5.608331
# sample5  2.710792  0.867280    7.534660
